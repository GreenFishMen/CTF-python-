# %%
import csv
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
sns.set(palette="muted", color_codes=True)
#sns.set_style({"font.sans-serif": ['simhei', 'Droid Sans Fallback']})
matplotlib.rcParams['axes.unicode_minus'] = False     # 正常显示负号
#matplotlib.rcParams['font.sans-serif'] = ['SimHei']   # 用黑体显示中文

# %%
from matplotlib.pyplot import MultipleLocator

datab = pd.read_csv('data/fbins__fp__database__395161.csvlen.distribution.csv')
#datab = pd.read_csv('data/video_tls.csv')
db = datab['length']
#w = np.random.normal(21.70443, 8.685057436616747, 10000)
#datar = pd.read_csv('data/loss_50_1.csv')
#dr = datar['len']
#sns.kdeplot(db, cumulative=True)
#sns.kdeplot(dr, cumulative=True)
sns.distplot(db, color='b', bins=500)
#sns.distplot(w, color='r', bins=500, hist=False)
plt.legend(loc='upper right')
plt.ylabel('PDF')
plt.xlabel("length")
plt.xlim(5120, 5200000)
#plt.xlabel("Packet loss rate of TCP flows")
#plt.legend(labels=['low','high'],loc='best')
#x_major_locator=MultipleLocator(5)
#ax=plt.gca()
#ax.xaxis.set_major_locator(x_major_locator)
plt.savefig('data/len_distrib.png', dpi=300)
#plt.savefig('data/TCP.loss.png', dpi=1200)
plt.show()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
np.mean(db)
